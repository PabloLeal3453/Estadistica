# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloLeal3453/Estadistica/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ##Probabilidad y estadistica
# #Unidad 1
#
# Practica 3. Maximo, mínimo, rango y dispersión de datos
#
# Maestro: Dr. José Gabriel Rodriguez Rivas
#
# Alumna: Pablo GAbriel Leal Nuñez

# %%
import random
import matplotlib.pyplot as plt
from statistics import *
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100), 2 )
  fabrica1.append(numero_aleatorio)
print(fabrica1)
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round( random.uniform(50, 100), 2 )
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [74.68, 90.83, 93.35, 57.31, 97.44, 54.59, 52.81, 87.89, 83.69, 71.74, 52.97, 62.45, 79.33, 67.8, 65.51, 88.78, 70.85, 54.58, 92.47, 79.6, 96.9, 90.67, 60.06, 67.09, 90.76, 74.53, 59.75, 60.28, 77.54, 83.98, 72.72, 77.15, 52.97, 77.06, 53.48, 64.02, 96.14, 50.12, 66.94, 96.93, 80.51, 91.12, 72.51, 98.22, 80.05, 88.39, 99.84, 55.88, 78.93, 98.01, 64.11, 96.19, 83.66, 54.61, 99.81, 66.77, 86.96, 58.4, 52.34, 53.48, 90.29, 98.75, 80.68, 60.89, 60.15, 87.35, 57.84, 57.12, 71.17, 81.55, 89.66, 99.01, 56.8, 83.12, 82.04, 84.07, 80.75, 85.81, 53.72, 81.45, 82.85, 98.96, 74.84, 66.74, 76.65, 75.07, 80.39, 94.94, 77.58, 78.15, 74.24, 80.88, 56.32, 61.64, 64.55, 92.28, 94.72, 84.89, 85.85, 55.19]
# [85.64, 68.86, 61.91, 75.22, 60.93, 57.43, 88.34, 58.83, 92.06, 86.18, 87.67, 55.92, 84.53, 60.75, 71.7, 71.5, 99.75, 60.61, 95.07, 52.55, 84.14, 63.85, 69.15, 79.24, 60.91, 64.97, 86.02, 84.15, 53.69, 83.68, 68.03, 58.78, 69.72, 73.06, 59.88, 95.14, 80.51, 77.51, 58.12, 65.2, 80.87, 72.04, 78.51, 71.39, 50.62, 86.85, 52.04, 70.09, 60.19, 76.62, 92.99, 95.38, 67.93, 92.66, 68.43, 58.67, 95.75, 91.49, 86.14, 64.53, 85.89, 75.69, 68.41, 51.21, 95.04, 89.89, 97.26, 51.21, 53.53, 71.34, 97.2, 83.09, 80.21, 63.79, 58.48, 59.89, 68.75, 77.62, 65.41, 60.44, 83.29, 90.43, 85.51, 89.59, 98.42, 81.77, 87.06, 85.03, 69.81, 61.42, 61.32, 88.6, 80.1, 93.77, 76.45, 50.41, 97.24, 67.19, 65.07, 95.57]

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1= maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("Estadistica descriptiva de la fabrica 1 \n", "Media =",media1,
      "\n Mediana =", mediana1,"\n Moda =", moda1,"\n Máximo =",maximo1,"\n Mínimo =",minimo1,"\n Rango =",rango1)
# Out:
# Estadistica descriptiva de la fabrica 1
#  Media = 76.065
#  Mediana = 77.86500000000001
#  Moda = 52.97
#  Máximo = 99.84
#  Mínimo = 50.12
#  Rango = 49.720000000000006

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2= maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("Estadistica descriptiva de la fabrica 2 \n", "Media =",media2,
      "\n Mediana =", mediana2,"\n Moda =", moda2,"\n Máximo =",maximo2,"\n Mínimo =",minimo2,"\n Rango =",rango2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  Media = 74.8679
#  Mediana = 74.14
#  Moda = 51.21
#  Máximo = 99.75
#  Mínimo = 50.41
#  Rango = 49.34

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
desviacion_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 14.75625677946186
# 14.009169601342968

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media1, color='b',linestyle='dashed', linewidth=2, label=f'Media={media1: .2f}')
plt.axvline(mediana1, color='r',linestyle='dashed', linewidth=2, label=f'Mediana={mediana1: .2f}')
plt.axvline(moda1, color='y',linestyle='dashed', linewidth=2, label=f'Moda={moda1: .2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica1: .2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='b',linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media2, color='b',linestyle='dashed', linewidth=2, label=f'Media={media2: .2f}')
plt.axvline(mediana2, color='r',linestyle='dashed', linewidth=2, label=f'Mediana={mediana2: .2f}')
plt.axvline(moda2, color='y',linestyle='dashed', linewidth=2, label=f'Moda={moda2: .2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica2: .2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='b',linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns
# La densidad gráfica es una forma de visualizar la distribución de datos
# en un intervalo o período de tiempo continuo.
# Se basa en un histograma que usaa el suavizado de kernel para trazar valores, lo que permite
# obtener distribuciones más suaves al reducir el ruido.
# Una curva de densidad muestra la ubicación de la media y la mediana de una distribución.
sns.histplot( x = fabrica1, kde = True, kde_kws = {'bw_adjust':0.5}, bins=10 )
# Out:
# <Axes: ylabel='Count'>
