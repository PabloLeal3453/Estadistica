# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloLeal3453/Estadistica/blob/main/Unidad3/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# #Probabilidad y Estadistica
# #Unidad 4
# ##Practica 1. Distribucion normal
# Facilitador: Dr.Jose Gabriel Rodriguez Rivas
#
# Grupo: 2YY
#
# Alumno: Pablo Gabriel Leal Nuñez

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
media = 70
desv_std = 4
num_datos = 500

datos = np.random.normal(media, desv_std, num_datos)
datos[0:50]
# Out:
# array([78.41645827, 61.8458587 , 73.80683689, 69.53663303, 72.35137095,
#        72.71038898, 67.14366368, 76.79732276, 66.73683615, 74.12689516,
#        70.62835746, 71.70359907, 71.71025047, 76.92469588, 68.56558996,
#        75.63471134, 71.15067588, 73.46908925, 66.60087806, 65.7155412 ,
#        70.28893869, 67.83335755, 64.13004361, 63.34803707, 68.24693757,
#        73.79422349, 68.59222292, 68.92978011, 69.76470951, 65.73060185,
#        71.51182217, 68.49847825, 71.19956838, 69.45484456, 71.54797916,
#        70.92323495, 67.15310818, 71.56050771, 66.84016499, 69.42680821,
#        69.70562091, 67.40982305, 63.77127109, 68.45710628, 73.24590078,
#        64.43389664, 71.58804861, 76.48400389, 68.5284482 , 73.2668359 ])

# %%
x = np.linspace(media - 3 * desv_std, media + 3 * desv_std, num_datos)
pdf = 1 / (desv_std * np.sqrt(2 * np.pi)) * np.exp(-(x - media)**2 / (2 * (desv_std**2)))

# %%
print("Imprimir lo primeros 50 valores de x", x[0:50], " y los pimeros 50 pdf", pdf[0:50])
# Out:
# Imprimir lo primeros 50 valores de x [58.         58.04809619 58.09619238 58.14428858 58.19238477 58.24048096
#  58.28857715 58.33667335 58.38476954 58.43286573 58.48096192 58.52905812
#  58.57715431 58.6252505  58.67334669 58.72144289 58.76953908 58.81763527
#  58.86573146 58.91382766 58.96192385 59.01002004 59.05811623 59.10621242
#  59.15430862 59.20240481 59.250501   59.29859719 59.34669339 59.39478958
#  59.44288577 59.49098196 59.53907816 59.58717435 59.63527054 59.68336673
#  59.73146293 59.77955912 59.82765531 59.8757515  59.9238477  59.97194389
#  60.02004008 60.06813627 60.11623246 60.16432866 60.21242485 60.26052104
#  60.30861723 60.35671343]  y los pimeros 50 pdf [0.00110796 0.00114858 0.0011905  0.00123379 0.00127846 0.00132455
#  0.00137211 0.00142118 0.00147178 0.00152397 0.00157777 0.00163325
#  0.00169042 0.00174935 0.00181007 0.00187262 0.00193706 0.00200342
#  0.00207176 0.00214212 0.00221455 0.0022891  0.00236581 0.00244475
# ...

# %%
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, color='b')
plt.title('Distribucion normal')
plt.xlabel('Peso en kg de los estudaintes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, pdf, label='Normal:(media:{}; ds:{})'.format(np.round(media, 2), np.round(desv_std, 2)))
plt.title('Funcion de Densidad de probabilidad (PDF) - Distribucion Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.hist(datos, bins =15, alpha=0.4, density=True, color='b')
plt.plot(x, pdf, 'k', linewidth=2 )
plt.title('Distribucion normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
media = 70
desv_std = 4
total_estudiantes = 500
peso_limite = 75
prob_menos_75kg = norm.cdf(peso_limite, media, desv_std)

# %%
estudiantes_menos_75kg = total_estudiantes * prob_menos_75kg
print("Probabilidad de que un estudiante pese menos de 75 kg", prob_menos_75kg)
print("Numero de estudiantes que pesan menos de 75kg", estudiantes_menos_75kg)

x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth =2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 75 kg.\n $ \mu =70$, $\sigma=4$, x =500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese menos de 75 kg 0.8943502263331446
# Numero de estudiantes que pesan menos de 75kg 447.1751131665723

# %%
plt.figure(figsize=(6, 4))
media = 70
desv_std = 4
total_estudiantes = 500
peso_limite = 62
prob_menos_62kg = norm.cdf(peso_limite, media, desv_std)
estudiantes_menos_62kg = total_estudiantes * prob_menos_62kg
print("Probabilidad de que un estudiante pese menos de 62 kg", prob_menos_62kg)
print("Numero de estudiantes que pesan menos de 62kg", estudiantes_menos_62kg)
# Out:
# Probabilidad de que un estudiante pese menos de 62 kg 0.022750131948179195
# Numero de estudiantes que pesan menos de 62kg 11.375065974089598

# %%
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth =2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 62 kg.\n $ \mu =70$, $\sigma=4$, x =500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
media = 70
desv_std = 4
total_estudiantes = 500
peso_limite = 79
prob_menos_79kg = norm.cdf(peso_limite, media, desv_std)
prob_mas_79kg = 1 - prob_menos_79kg
estudiantes_mas_79kg = total_estudiantes * prob_mas_79kg
print("Probabilidad de que un estudiante pese mas de 79 kg", prob_mas_79kg)
print("Numero de estudiantes que pesan mas de 79kg", estudiantes_mas_79kg)
# Out:
# Probabilidad de que un estudiante pese mas de 79 kg 0.012224472655044671
# Numero de estudiantes que pesan mas de 79kg 6.112236327522336

# %%
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth =2)
plt.fill_between(x, y, where=(x >= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese mas de 79 kg.\n $ \mu =70$, $\sigma=4$, x =500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
media = 70
desv_std = 4
total_estudiantes = 500
peso_limite = 68
peso_limite2 = 72
prob_mas_68kg = norm.cdf(peso_limite, media, desv_std)
prob_menos_79kg = norm.cdf(peso_limite, media, desv_std)
prob_mas_79kg = 1 - prob_menos_79kg
prob_medio = prob_menos_72kg - prob_mas_68kg
estudiantes_mas_79kg = total_estudiantes * prob_mas_79kg
estudiantes_mas_68kg = total_estudiantes * prob_mas_68kg
edstudiantes_medio = estudiantes_mas_79kg - estudiantes_mas_68kg
print("Probabilidad de que un estudiante pese mas de 68 kg y menos de 72kg", prob_medio)
print("Numero de estudiantes que pesan mas de 68kg y menos de 72kg", estudiantes_mas_68kg)
# Out:
# Probabilidad de que un estudiante pese mas de 68 kg y menos de 72kg 0.38292492254802624
# Numero de estudiantes que pesan mas de 68kg y menos de 72kg 154.26876936299345

# %%
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth =2)
plt.fill_between(x, y, where=(x >= peso_limite) & (x < peso_limite2), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese mas de 68 y menos de 72 kg.\n $ \mu =70$, $\sigma=4$, x =500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
